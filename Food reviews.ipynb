# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import nltk

import re
import contractions
import emoji


from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

nltk.download("punkt")
nltk.download("punkt_tab")   
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# **DATA PREPARATION**

# %%
df = pd.read_csv(r"C:\Users\USER\Desktop\python projects\food_reviews (1).csv")
df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# ...

# %%
df.shape
# Out:
# (568454, 13)

# %%
df.columns
# Out:
# Index(['Id', 'ProductId', 'UserId', 'ProfileName', 'HelpfulnessNumerator',
#        'HelpfulnessDenominator', 'Score', 'Time', 'Summary', 'Text'],
#       dtype='object')

# %%
df.columns.str.strip().str.lower().str.replace(" ","_")
# Out:
# Index(['id', 'productid', 'userid', 'profilename', 'helpfulnessnumerator',
#        'helpfulnessdenominator', 'score', 'time', 'summary', 'text'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Id                         int64
# ProductId                 object
# UserId                    object
# ProfileName               object
# HelpfulnessNumerator       int64
# HelpfulnessDenominator     int64
# Score                      int64
# Time                       int64
# Summary                   object
# Text                      object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 568454 entries, 0 to 568453
# Data columns (total 10 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   Id                      568454 non-null  int64
#  1   ProductId               568454 non-null  object
#  2   UserId                  568454 non-null  object
#  3   ProfileName             568428 non-null  object
#  4   HelpfulnessNumerator    568454 non-null  int64
#  5   HelpfulnessDenominator  568454 non-null  int64
#  6   Score                   568454 non-null  int64
#  7   Time                    568454 non-null  int64
#  8   Summary                 568427 non-null  object
#  9   Text                    568454 non-null  object
# dtypes: int64(5), object(5)
# memory usage: 43.4+ MB

# %%
df.isnull().sum()
# Out:
# Id                         0
# ProductId                  0
# UserId                     0
# ProfileName               26
# HelpfulnessNumerator       0
# HelpfulnessDenominator     0
# Score                      0
# Time                       0
# Summary                   27
# Text                       0
# dtype: int64

# %%
df.head(2)
# Out:
#    Id   ProductId          UserId ProfileName  HelpfulnessNumerator  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW  delmartian                     1
# 1   2  B00813GRG4  A1D87F6ZCVE5NK      dll pa                     0
#
#    HelpfulnessDenominator  Score        Time                Summary  \
# 0                       1      5  1303862400  Good Quality Dog Food
# 1                       0      1  1346976000      Not as Advertised
#
#                                                 Text
# 0  I have bought several of the Vitality canned d...
# 1  Product arrived labeled as Jumbo Salted Peanut...

# %%
df.isnull().sum()
# Out:
# Id                         0
# ProductId                  0
# UserId                     0
# ProfileName                0
# HelpfulnessNumerator       0
# HelpfulnessDenominator     0
# Score                      0
# Time                       0
# Summary                   27
# Text                       0
# dtype: int64

# %%
df["Summary"].fillna("unkown", inplace = True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_26760\552425762.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Summary"].fillna("unkown", inplace = True)

# %%
df.isnull().mean()*100
# Out:
# Id                        0.0
# ProductId                 0.0
# UserId                    0.0
# ProfileName               0.0
# HelpfulnessNumerator      0.0
# HelpfulnessDenominator    0.0
# Score                     0.0
# Time                      0.0
# Summary                   0.0
# Text                      0.0
# dtype: float64

# %%
#df.value_counts()
# Out:
# Id      ProductId   UserId          ProfileName                      HelpfulnessNumerator  HelpfulnessDenominator  Score  Time        Summary                             Text
# 1       B001E4KFG0  A3SGXH7AUHU8GW  delmartian                       1                     1                       5      1303862400  Good Quality Dog Food               I have bought several of the Vitality canned dog food products and have found them all to be of good quality. The product looks more like a stew than a processed meat and it smells better. My Labrador is finicky and she appreciates this product better than  most.                                                                                                                                                                                                                                                          1
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Text"].str.len().describe()
# Out:
# count    568454.000000
# mean        436.222083
# std         445.339741
# min          12.000000
# 25%         179.000000
# 50%         302.000000
# 75%         527.000000
# max       21409.000000
# Name: Text, dtype: float64

# %%
df.columns = df.columns.str.lower()

# %%
df.head(2)
# Out:
#    id   productid          userid profilename  helpfulnessnumerator  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW  delmartian                     1
# 1   2  B00813GRG4  A1D87F6ZCVE5NK      dll pa                     0
#
#    helpfulnessdenominator  score        time                summary  \
# 0                       1      5  1303862400  Good Quality Dog Food
# 1                       0      1  1346976000      Not as Advertised
#
#                                                 text  \
# 0  i have bought several of the vitality canned d...
# 1  product arrived labeled as jumbo salted peanut...
#
#                                           clean_text  \
# 0  i have bought several of the vitality canned d...
# 1  product arrived labeled as jumbo salted peanut...
#
#                                               tokens  \
# 0  [i, have, bought, several, of, the, vitality, ...
# 1  [product, arrived, labeled, as, jumbo, salted,...
#
#                                         tokens_clean
# ...

# %%
df["text"] = df["text"].str.lower()

# %%
df["text"].head(3)
# Out:
# 0    i have bought several of the vitality canned d...
# 1    product arrived labeled as jumbo salted peanut...
# 2    this is a confection that has been around a fe...
# Name: text, dtype: object

# %%
all_punct = df["text"].apply(lambda t: re.findall(r"[^\w\s]", t))
unique_chars = set(char for row in all_punct for char in row)
print(unique_chars)
# Out:
# {'[', '£', '&', '\x07', '\\', '*', '#', ';', '¨', '×', '"', '<', '®', ':', '`', '»', ',', '¢', '+', '$', '%', ']', "'", '-', '·', '@', '^', '±', '~', '\xad', '¦', ')', '/', '\x0f', '.', '=', '\x06', '¬', '!', '?', '\x13', '(', '\x8c', '|', '>', '°', '\x10', '§', '\x99', '«', '©', '}', '{'}

# %%
count_punct = df["text"].apply(lambda t: len(re.findall (r"[^\w\s]", t)))
count_punct
# Out:
# 0          3
# 1          7
# 2         18
# 3          5
# 4          5
#           ..
# 568449     8
# 568450     9
# 568451    11
# 568452     3
# 568453     5
# Name: text, Length: 568454, dtype: int64

# %%
df["clean_text"] = df["text"].str.replace(r"[^\w\s!?]", " ", regex = True)

# %%
df["clean_text"] = df["clean_text"].str.replace(r"http\S+|www\S+", "", regex=True)
df["clean_text"] = df["clean_text"].str.replace(r"<.*?>", "", regex=True)
df["clean_text"] = df["clean_text"].str.replace(r"@\w+", "", regex=True)
df["clean_text"] = df["clean_text"].str.replace(r"#", "", regex=True)
df["clean_text"] = df["clean_text"].str.replace(r"\S+@\S+", "", regex=True)

# %%
# function to clean a text column

def clean_text(text):
    text = text.lower()
    text = contractions.fix(text)                       
    text = emoji.demojize(text, delimiters=(" ", " "))  
    text = re.sub(r"http\S+|www\S+", " ", text)
    text = re.sub(r"<.*?>", " ", text)
    text = re.sub(r"@\w+", " ", text)
    text = re.sub(r"#", "", text)
    text = re.sub(r"\S+@\S+", " ", text)
    text = re.sub(r"(.)\1{2,}", r"\1\1", text)            # soooo -> soo
    text = re.sub(r"[^\w\s!?]", " ", text)
    text = re.sub(r"\d+", " ", text)
    text = re.sub(r"\s+", " ", text).strip()
    return text

df["clean_text"] = df["text"].apply(clean_text)

# %%
import nltk
nltk.download("stopwords")
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\USER\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
df["tokens"] = df["clean_text"].apply(word_tokenize)

# %%
df["tokens"].head(2)
# Out:
# 0    [i, have, bought, several, of, the, vitality, ...
# 1    [product, arrived, labeled, as, jumbo, salted,...
# Name: tokens, dtype: object

# %%
stop_words = set(stopwords.words("english"))
negation_words = {"not", "no", "never", "nor"}
stop_words = stop_words - negation_words

# %%
df["tokens_clean"] = df["tokens"].apply(lambda x: [w for w in x if w not in stop_words])
df["tokens_clean"].head(2)
# Out:
# 0    [bought, several, vitality, canned, dog, food,...
# 1    [product, arrived, labeled, jumbo, salted, pea...
# Name: tokens_clean, dtype: object
